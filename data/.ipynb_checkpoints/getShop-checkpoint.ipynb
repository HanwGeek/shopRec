# %%
import pymongo
import requests
import jieba
import jieba.analyse
import base64
import random
import time
import zlib
import json

# %%
URL = 'https://wh.meituan.com/meishi/'
_cookies = ['_lxsdk_s=b458c64cc9ef92adce92c199a6b7%7C%7C4; __mta=214784936.1512623224439.1512623224439.1512623226558.2; client-id=8d050bd8-51b6-46fc-be96-cb6871d91fe7; ci=89; webloc_geo=31.778615%2C119.958931%2Cwgs84; _lxsdk=1602f5eb154c8-05c63a41825c168-1b451e24-13c680-1602f5eb154c8; uuid=73a65301-f351-4cdd-bfcd-35ae40aea13c',
           '_lxsdk_s=55618265813fc43043ce562acf29%7C%7C2; ci=89; __mta=252597174.1512623399814.1512623399814.1512623399814.1; _lxsdk=1602f6161c1c8-034ae66c3842d88-1b451e24-13c680-1602f6161c170; client-id=8ca2fe5f-ba96-41ae-b919-f8d3665e2f10; webloc_geo=31.778620%2C119.958935%2Cwgs84; uuid=ae73c608-8db3-4724-b4bf-91f4a8c701c5',
           '_lxsdk_s=4ffb12d5a90c2361745e6d0993a2%7C%7C2; ci=89; __mta=40613533.1512623465821.1512623465821.1512623465821.1; client-id=a31f1c79-3287-4ef1-8bd3-56bfb431a7da; webloc_geo=31.778616%2C119.958936%2Cwgs84; _lxsdk=1602f6262117d-0f173d7fde38d18-1b451e24-13c680-1602f626212c8; uuid=ba1b457e-ae34-4b56-bf7b-9bf3579ac0ae',
           '_lxsdk_s=4ba654e682eaf4d69efb90ae9cf1%7C%7C2; __mta=152351622.1512623525333.1512623525333.1512623525333.1; ci=89; client-id=e8101f58-a778-4332-81c2-75ba410b2bb3; webloc_geo=31.778611%2C119.958934%2Cwgs84; _lxsdk=1602f634c448d-0c74adf6d00e2e8-1b451e24-13c680-1602f634c45c8; uuid=e98a7e32-7511-4b40-ab3d-d88011a06471',
           '_lxsdk_s=f6511ca715103c33b7bb4aea1e9f%7C%7C2; __mta=40629917.1512623573270.1512623573270.1512623573270.1; ci=89; client-id=c69db65e-b5d1-4fe6-aa7a-340e3608aeb6; webloc_geo=31.778617%2C119.958930%2Cwgs84; _lxsdk=1602f64072fc8-04cf33034885b08-1b451e24-13c680-1602f640730c8; uuid=33b52a9f-14ea-4f80-9a97-8386fc9fb0a2',
           '_lxsdk_s=38327d7cfda78d0cfc4810838c32%7C%7C2; __mta=150795529.1512623625315.1512623625315.1512623625315.1; ci=89; client-id=221306b1-bfb7-4cfa-ab3f-2e4a85089864; webloc_geo=31.778610%2C119.958933%2Cwgs84; _lxsdk=1602f64d24531-0623a27320ba75-1b451e24-13c680-1602f64d246c8; uuid=85f7949c-284c-4ae6-b5f8-18aa1c6dc016',
           '_lxsdk_s=c2f111bde916cad4d653e07a35c9%7C%7C2; __mta=42950426.1512623702441.1512623702441.1512623702441.1; _lxsdk=1602f66000dc8-0bb60c750cf17b8-1b451e24-13c680-1602f66000d7f; ci=89; client-id=38cc3a86-fe57-491b-8564-c9b1a251cd4a; webloc_geo=31.778617%2C119.958931%2Cwgs84; uuid=095c6c87-a397-4cc4-a3fc-1c3e35eca3be',
           '_lxsdk_s=fd711080efee1adf6de57c1d4c88%7C%7C2; ci=89; webloc_geo=31.778612%2C119.958939%2Cwgs84; __mta=218070313.1512623752950.1512623752950.1512623752950.1; _lxsdk=1602f66c53e35-0b363d23b0e435-1b451e24-13c680-1602f66c53fc8; client-id=1a4a2af3-4201-4e61-bf26-92016709444b; uuid=9361e591-ada9-43c0-a762-b7b5559c649a',
           '_lxsdk_s=810677247f21b53cd75826e60cb8%7C%7C2; __mta=146594315.1512623869611.1512623869611.1512623869611.1; _lxsdk=1602f688ce80-074a1ec97ff043-1b451e24-13c680-1602f688ce9c8; ci=89; client-id=e60488fa-51fe-4d12-99a3-257a5a0853cc; webloc_geo=31.778609%2C119.958928%2Cwgs84; uuid=948eec52-7d10-46ce-b689-92140842f3f0',
           '_lxsdk_s=c44c26606c13c651ab5a20447428%7C%7C2; __mta=89516452.1512623906613.1512623906613.1512623906613.1; _lxsdk=1602f691da0c8-024ebcb15833bc-1b451e24-13c680-1602f691da04b; ci=89; client-id=a6846506-a50a-4612-8106-ff31978802a8; webloc_geo=31.778607%2C119.958929%2Cwgs84; uuid=6ee14a07-2d20-460e-87c2-001806dfdf1b',
           '_lxsdk_s=071dfe26ce64d6e46d03323d2f71%7C%7C2; __mta=210099498.1512623985254.1512623985254.1512623985254.1; ci=89; client-id=f2cea0fa-0d83-479a-a863-f2b7156fb392; webloc_geo=31.778621%2C119.958925%2Cwgs84; _lxsdk=1602f6a4f88c8-0ce1602d9c121a-1b451e24-13c680-1602f6a4f88c8; uuid=122a1bf8-f588-4b2d-a509-2bb45aaf1be9',
           '_lxsdk_s=833017bd50026c6c57b327f1f51a%7C%7C2; __mta=244702778.1512624031536.1512624031536.1512624031536.1; ci=89; client-id=ec7106e4-9dda-4ce0-aa8d-c12288812644; webloc_geo=31.778622%2C119.958921%2Cwgs84; _lxsdk=1602f6b0459c8-011b3f8b51c9328-1b451e24-13c680-1602f6b045ac8; uuid=04d6dbed-d679-4e9d-a0c7-4ea1b2343513',
           '_lxsdk_s=9a68aaba42beb1ebdfc3e726d94e%7C%7C2; ci=89; webloc_geo=31.778629%2C119.958912%2Cwgs84; __mta=45406747.1512624277952.1512624277952.1512624277952.1; _lxsdk=1602f6ec7b84-095c2ecf9438458-1b451e24-13c680-1602f6ec7b9c8; uuid=33acafd1-4a03-4f0f-9572-1ccbfd570efc; client-id=77353c1f-ba56-4ac9-bbb3-c7a689858182',
           '_lxsdk_s=c1508df449b0616ba37c5d9166f2%7C%7C2; __mta=216814121.1512624317347.1512624317347.1512624317347.1; ci=89; client-id=5d8e3ff2-5370-4c08-855e-9d26e5187040; webloc_geo=31.778633%2C119.958912%2Cwgs84; _lxsdk=1602f6f6187a2-029abec138ea508-1b451e24-13c680-1602f6f6188c8; uuid=1a808ef4-511d-44ba-acfd-d6339ddb92f8',
           '_lxsdk_s=7a249ecc9a048cbb826ea3b1f4e7%7C%7C2; __mta=256753588.1512624355644.1512624355644.1512624355644.1; _lxsdk=1602f6ff822c8-01f025c7119f968-1b451e24-13c680-1602f6ff823c8; ci=89; client-id=33339c7c-4dd0-4da8-8617-add389e72438; webloc_geo=31.778634%2C119.958912%2Cwgs84; uuid=92e531c6-4620-453e-ad8d-0e67644404ad',
           '_lxsdk_s=93f6847b5f37e552ae083beb48c2%7C%7C2; __mta=218397606.1512624389136.1512624389136.1512624389136.1; ci=89; client-id=21540b20-0240-48fa-ae1e-c1ce4dba892f; webloc_geo=31.778631%2C119.958925%2Cwgs84; _lxsdk=1602f707a3d3-0d7db668e6d9498-1b451e24-13c680-1602f707a3ec8; uuid=507d006a-6b37-4ff9-9299-88eae1bc0982',
           '_lxsdk_s=0ffdd4e2dddd57d3c05606eb82f3%7C%7C2; __mta=141367821.1512624428164.1512624428164.1512624428164.1; ci=89; client-id=d6e8de67-48b8-4262-b3b3-47851c46db5c; webloc_geo=31.778620%2C119.958977%2Cwgs84; _lxsdk=1602f7112b9c8-09d6e858772c1d8-1b451e24-13c680-1602f7112bac8; uuid=2b6ac2bf-62cf-4ebd-bb68-bd0c258c6b29',
           ]
cookie = '_lxsdk_cuid=16a2f66fef2c8-04adb68a07ed52-e323069-130980-16a2f66fef2c8; ci=57; rvct=57; _hc.v=1197cd1c-6791-15f8-9279-cd9a57fde16c.1555573509; _lx_utm=utm_source%3Dgoogle%26utm_medium%3Dorganic; _lxsdk=16a2f66fef2c8-04adb68a07ed52-e323069-130980-16a2f66fef2c8; __mta=251043129.1555573459093.1555902899880.1555913774718.3; client-id=dc69c296-2418-478e-bb1c-b5dc4676a0b5; uuid=388dc241-38f9-4e12-bc70-c9898b7c1c1c; _lxsdk_s=16a48f9f2c4-2f-01c-78c%7C%7C38'
headers = {
  'Accept':'application/json',
  'Accept-Encoding': 'gzip, deflate',
  'Accept-Language': 'en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7',
  'Connection': 'keep-alive',
  'Cookie': cookie,
  'Host': 'wh.meituan.com',
  'Referer': 'http://wh.meituan.com/meishi/',
  'User-Agent':' Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'
}
URL = 'https://wh.meituan.com/meishi/api/poi/'

# %%
# Constant
client = pymongo.MongoClient("mongodb://101.132.171.223:27017/")
db = client['shoprec']
totalCount = 1000
pageNum = 67

# %%
class Token():
    def __init__(self, cateId, areaId, originUrl, page):
        self.areaId = areaId
        self.cityName = '武汉'
        self.originUrl = originUrl
        self.page = page
        self.uuid = '765ddffde8444259bfe4.1556036967.1.0.0'
        self.cateId = cateId

    def join_sign(self):
        # 参数
        sign = 'cityName={cityName}&areaId={areaId}&cateId={cateId}&dinnerCountAttrId=&optimusCode=1&originUrl={originUrl}&page={page}&partner=126&platform=1&riskLevel=1&sort=&userId=&uuid={uuid}'
        _str = sign.format(areaId=self.areaId, cateId=self.cateId, cityName=self.cityName, originUrl=self.originUrl, page=self.page,
                           uuid=self.uuid)
        sign = base64.b64encode(zlib.compress(bytes(json.dumps(_str, ensure_ascii=False), encoding="utf8")))
        sign = str(sign, encoding="utf8")
        return sign

    @property
    def join_token(self):
        str_json = {}
        str_json['rId'] = 100900
        str_json['ver'] = '1.0.6'
        str_json['ts'] = time.time()
        str_json['cts'] = time.time() + 110
        str_json['brVD'] = [1920, 315]
        str_json['brR'] = [[1920, 1080], [1920, 1057], 24, 24]
        str_json['bI'] = [self.originUrl, ""]
        str_json['mT'] = []
        str_json['kT'] = []
        str_json['aT'] = []
        str_json['tT'] = []
        str_json['aM'] = ''
        str_json['sign'] = self.join_sign()
        token_decode = zlib.compress(
            bytes(json.dumps(str_json, separators=(',', ':'), ensure_ascii=False), encoding="utf8"))
        token = str(base64.b64encode(token_decode), encoding="utf8")
        return token

# %%
def getPoiList(cateId, areaId, page, originUrl):
    url = URL + 'getPoiList'
    _token = Token(cateId, areaId, page, originUrl)
    _params = {
        'cityName': '武汉',
        'cateId': cateId,
        'areaId': areaId,
        'page': page,
        'uuid': '765ddffde8444259bfe4.1556036967.1.0.0',
        'originUrl': originUrl,
        '_token': _token.join_token,
        'platform': 1,
        'partner': 126,
        'riskLevel': 1,
        'optimusCode': 1,
        'sort':'',
        'dinnerCountAttrId':'',
        'userId':''
    }
    content = requests.get(url, headers=headers, params=_params)
    return json.loads(content.text, encoding='utf8')

def getType():
    col = db['cate']
    types = col.find()
    return list(types)

def getPoiByCate(cate):
    name = cate['name']
    cateId = cate['cateId']
    url = cate['url']
    
    shops = []
    areaId = 0
    for page in range(1, pageNum + 1):
        originUrl = URL + url + '/pn' + str(page)
        res = getPoiList(cateId, areaId, page, originUrl)
        data = res['data']['poiInfos']
        data = list(map(lambda x: {
            'id': x['poiId'],
            'title': x['title'],
            'address': x['address'],
            'avgPrice': x['avgPrice'],
            'avgScore': x['avgScore'],
            'allCommentNum': x['allCommentNum'],
            'cate': name,
            'cateId': cateId
        }, data))
        shops += data
    return shops

# %%
_types = list(map(lambda x: {'name': x['name'], 'cateId': x['cateId'][1:], 'url': x['cateId']}, getType()))

# %%
cate = _types[0]
data= getPoiByCate(cate)

# %%
len(data)
# Out:
# 1005

# %%
for cate in _types:
    data = getPoiByCate(cate)
    print("Getting...", cate['name'])
# Out:
# [{'address': '江岸区二七路89号东立国际二期22栋1层125室',
#   'allCommentNum': 41,
#   'avgPrice': 0,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 179377162,
#   'title': '欧菲克蛋糕（二七路店）'},
#  {'address': '硚口区万安国际23楼2310室（地铁六号线武胜路站A出口向硚口方向前行40米至操场角路口）',
#   'allCommentNum': 797,
#   'avgPrice': 104,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6873328,
#   'title': '八喜蛋糕（武胜路凯德店）'},
#  {'address': '洪山区虎泉创意坊1楼（地铁二号线虎泉站）',
#   'allCommentNum': 2708,
#   'avgPrice': 13,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5633439,
#   'title': '海贼王主题冰淇淋'},
#  {'address': '江岸区江汉北路56-64号',
#   'allCommentNum': 31,
#   'avgPrice': 0,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 161529457,
#   'title': '欧菲克蛋糕店（江汉北路店）'},
#  {'address': '硚口区解放大道387号南国西汇城市广场一期1层',
#   'allCommentNum': 2573,
#   'avgPrice': 13,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 52159591,
#   'title': '蛋挞皇后（南国西汇城市广场店）'},
#  {'address': '洪山区珞喻路998号光谷国际广场（中心花园第A幢A层099号房，近鲁巷广场，光谷大洋百货）',
#   'allCommentNum': 2045,
#   'avgPrice': 0,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42522908,
#   'title': '幸福时光蛋糕（光谷广场店）'},
#  {'address': '青山区和平大道1095号青宜生活家生鲜市场sp41号铺面（工人村街社区卫生服务中心对面）',
#   'allCommentNum': 80,
#   'avgPrice': 20,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 101617966,
#   'title': '麦客蛋糕面包西饼（青宜居店）'},
#  {'address': '武昌区烈士街84号（首义广场旁）',
#   'allCommentNum': 4380,
#   'avgPrice': 57,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 2554256,
#   'title': '欧尚蛋糕（首义店）'},
#  {'address': '蔡甸区东风大道111号万达广场万达金街C51（出万达广场3号门右拐斜对面）',
#   'allCommentNum': 6159,
#   'avgPrice': 24,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4647522,
#   'title': '榴芒记（万达广场店）'},
#  {'address': '洪山区光谷青年城6号楼2F025号',
#   'allCommentNum': 215,
#   'avgPrice': 91,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 184187692,
#   'title': '慕喜客蛋糕（青年城店）'},
#  {'address': '新洲区中心城区齐安大道307号',
#   'allCommentNum': 1497,
#   'avgPrice': 19,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4570262,
#   'title': '老好人蛋糕（新洲店）'},
#  {'address': '蔡甸区中核世纪广场1楼步行街1号',
#   'allCommentNum': 2201,
#   'avgPrice': 7,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 51769289,
#   'title': '豆花妈妈（中核店）'},
#  {'address': '硚口区汉西一路南国大家装R座2栋1017室',
#   'allCommentNum': 2,
#   'avgPrice': 772,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 159364498,
#   'title': '花开泛糖甜品台及蛋糕定制'},
#  {'address': '洪山区湖北第二师范学院佳源花都商业街中间A-13号铺（晨光文具旁，光谷金融港附近）',
#   'allCommentNum': 3341,
#   'avgPrice': 34,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6379458,
#   'title': '米兰西饼生日蛋糕（佳源花都商业街店）'},
#  {'address': '汉阳区人信汇商业广场地下一层B区B-063-3、B-065号商铺（龙阳村地铁站D口附近）',
#   'allCommentNum': 3487,
#   'avgPrice': 9,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5067722,
#   'title': '吾饮良品（人信汇店）'},
#  {'address': '洪山区友谊大道973号（工业四与友谊大道基础口现代花社区A区公交车站正后面）',
#   'allCommentNum': 254,
#   'avgPrice': 20,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5817578,
#   'title': '麦客蛋糕（现代花园店）'},
#  {'address': '洪山区珞狮南路147号未来城购物公园F1层中庭（骰子镇桌游吧旁）',
#   'allCommentNum': 1227,
#   'avgPrice': 14,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40292548,
#   'title': '贡茶（未来城店）'},
#  {'address': '青山区友谊大道园林路钢都花园127街82门12号',
#   'allCommentNum': 857,
#   'avgPrice': 0,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40326755,
#   'title': '永恒时光（武汉）食品有限公司（青山店）'},
#  {'address': '汉阳区汉阳区龙阳凯悦大厦B座',
#   'allCommentNum': 654,
#   'avgPrice': 87,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 168893293,
#   'title': '慕喜客私房蛋糕（汉阳店）'},
#  {'address': '洪山区民族大道中南民族大学校门口接待中心',
#   'allCommentNum': 1972,
#   'avgPrice': 21,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 747920,
#   'title': '楚天帝冠蛋糕（民族大学店）'},
#  {'address': '蔡甸区经济技术开发区湘隆时代商业中心A区9-13号',
#   'allCommentNum': 2232,
#   'avgPrice': 10,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41514257,
#   'title': 'A咖时尚饮品（湘隆店）'},
#  {'address': '洪山区新竹路五号光谷青年城6栋',
#   'allCommentNum': 3,
#   'avgPrice': 88,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 185739525,
#   'title': '乐佳蛋糕（青年城店）'},
#  {'address': '武昌区武汉大学工学部青年教师公寓30栋107室（田园小观园附近）',
#   'allCommentNum': 301,
#   'avgPrice': 10,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42183217,
#   'title': '黑龍茶（武大街道口店）'},
#  {'address': '武昌区武汉湖北大学学院路-1号',
#   'allCommentNum': 1202,
#   'avgPrice': 10,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4787775,
#   'title': '梅花王蛋糕（湖大店）'},
#  {'address': '洪山区珞狮路鹏程国际',
#   'allCommentNum': 54,
#   'avgPrice': 123,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 164200815,
#   'title': '王子蛋糕'},
#  {'address': '洪山区珞喻路肯德基隔壁（鲁巷广场外）',
#   'allCommentNum': 1651,
#   'avgPrice': 25,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6166473,
#   'title': '答案茶（光谷店）'},
#  {'address': '江汉区常青街银河里66号欧亚达国际广场汉口店B1层',
#   'allCommentNum': 396,
#   'avgPrice': 12,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41395729,
#   'title': '柠檬王子（欧亚达国际广场汉口店）'},
#  {'address': '江汉区雪松路231号夏氏砂锅旁',
#   'allCommentNum': 5,
#   'avgPrice': 80,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 177410267,
#   'title': '梅姐私房蛋糕（万松园店）'},
#  {'address': '蔡甸区宁康路58号湘隆时代广场A区10栋10号',
#   'allCommentNum': 1588,
#   'avgPrice': 20,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 742113,
#   'title': '台北蛋糕（湘隆店）'},
#  {'address': '汉南区中心城区百花街258号',
#   'allCommentNum': 2310,
#   'avgPrice': 10,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41537285,
#   'title': '吾饮良品'},
#  {'address': '汉阳区汉阳大道577号汉商21世纪购物中心1楼（数码箱包部）',
#   'allCommentNum': 78,
#   'avgPrice': 25,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 182398488,
#   'title': 'Queen·D女王的面包私人蛋糕订制'},
#  {'address': '洪山区虎泉创意坊1楼（地铁二号线虎泉站）',
#   'allCommentNum': 2708,
#   'avgPrice': 13,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5633439,
#   'title': '海贼王主题冰淇淋'},
#  {'address': '蔡甸区中核世纪广场1楼步行街1号',
#   'allCommentNum': 2201,
#   'avgPrice': 7,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 51769289,
#   'title': '豆花妈妈（中核店）'},
#  {'address': '武昌区松竹路万达环球国际中心2号楼512（洱湾酒店楼上）',
#   'allCommentNum': 50,
#   'avgPrice': 60,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 178771279,
#   'title': '北岛烘焙'},
#  {'address': '洪山区街道口未来城c1119（群光广场）',
#   'allCommentNum': 283,
#   'avgPrice': 45,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42960793,
#   'title': '白熊甜品店（街道口店）'},
#  {'address': '硚口区万安国际23楼2310室（地铁六号线武胜路站A出口向硚口方向前行40米至操场角路口）',
#   'allCommentNum': 797,
#   'avgPrice': 104,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6873328,
#   'title': '八喜蛋糕（武胜路凯德店）'},
#  {'address': '江夏区光谷一路水晶郦都大门正对面',
#   'allCommentNum': 44,
#   'avgPrice': 0,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 165590049,
#   'title': '幸汇里蛋糕'},
#  {'address': '武昌区武珞路中南国际城A座1楼门面1（金逸影城旁）',
#   'allCommentNum': 1474,
#   'avgPrice': 49,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42274720,
#   'title': '咖啡陪你（中南店）'},
#  {'address': '东西湖区马池路银湖九号（轻工大学南2门斜对面）',
#   'allCommentNum': 49,
#   'avgPrice': 30,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 51145918,
#   'title': '依伊私房蛋糕'},
#  {'address': '江岸区武汉市江岸区山海关路3附4号（付先生在成都旁边）',
#   'allCommentNum': 0,
#   'avgPrice': 44,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 192425548,
#   'title': '一月甜品店'},
#  {'address': '武昌区彭刘杨西路汉飞逛逛街3号楼3119室（司门口天桥美特斯邦威旁边）民主路司门口天桥美特斯邦威旁（快捷酒店旁）',
#   'allCommentNum': 95,
#   'avgPrice': 9,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41349174,
#   'title': '吾饮良品'},
#  {'address': '洪山区民族大道中南民族大学校门口接待中心',
#   'allCommentNum': 1972,
#   'avgPrice': 21,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 747920,
#   'title': '楚天帝冠蛋糕（民族大学店）'},
#  {'address': '武昌区楚河汉街松竹路万达广场三楼',
#   'allCommentNum': 124,
#   'avgPrice': 23,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 188267785,
#   'title': '芝芝舒芙蕾（武昌店）'},
#  {'address': '武昌区武汉大学工学部青年教师公寓30栋107室（田园小观园附近）',
#   'allCommentNum': 301,
#   'avgPrice': 10,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42183217,
#   'title': '黑龍茶（武大街道口店）'},
#  {'address': '江岸区田元二村24号2单元1层4室',
#   'allCommentNum': 57,
#   'avgPrice': 15,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1896755,
#   'title': '华康蛋糕'},
#  {'address': '江汉区新华路万达室外步行街D021',
#   'allCommentNum': 36,
#   'avgPrice': 54,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 181414646,
#   'title': '花漾·时光烘焙（菱角湖万达店）'},
#  {'address': '洪山区光谷步行街四楼火星美食城',
#   'allCommentNum': 1113,
#   'avgPrice': 9,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42268636,
#   'title': '柠檬王子（天空城店）'},
#  {'address': '东西湖区吴中街沿海国际中心办公楼8栋705室',
#   'allCommentNum': 693,
#   'avgPrice': 25,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42163955,
#   'title': '品冠蛋糕（东西湖店）'},
#  {'address': '江汉区唐家墩路5号武汉菱角湖万达广场A区A栋/单元3层02室',
#   'allCommentNum': 0,
#   'avgPrice': 0,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169179085,
#   'title': '万达宝贝王DIY烘培教室'},
#  {'address': '汉阳区蔡正路,（老中百仓储对面），政府西侧200米左右（近工商银行）',
#   'allCommentNum': 343,
#   'avgPrice': 13,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6725590,
#   'title': '梅花王蛋糕（中百总店）'},
#  {'address': '武昌区福客茂1层（美妃名发世家旁）',
#   'allCommentNum': 336,
#   'avgPrice': 11,
#   'avgScore': 4.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6052090,
#   'title': '下一站奶茶文化专门店（福客茂店）'},
#  {'address': '汉阳区金龙路玫瑰园小区G3栋1层9号商铺尚品足道旁',
#   'allCommentNum': 1,
#   'avgPrice': 0,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 191448559,
#   'title': '慕喜客蛋糕'},
#  {'address': '黄陂区板桥大道147号',
#   'allCommentNum': 435,
#   'avgPrice': 0,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1899318,
#   'title': '王中王蛋糕（板桥大道店）'},
#  {'address': '洪山区光谷步行街世界城新尚都1826（光谷步行街广场车站必胜客旁通道上2楼电梯口）',
#   'allCommentNum': 1538,
#   'avgPrice': 17,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1032903,
#   'title': '多喜西饼（光谷店）'},
#  {'address': '青山区和平大道819号奥山世纪城B1层',
#   'allCommentNum': 1538,
#   'avgPrice': 12,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5360800,
#   'title': '泡芙时代手工烘焙工坊（奥山世纪城店）'},
#  {'address': '洪山区珞喻路726号鲁巷广场购物中心B1层',
#   'allCommentNum': 1253,
#   'avgPrice': 41,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5646903,
#   'title': 'BPS八布工坊（鲁巷广场购物中心店）'},
#  {'address': '洪山区街道口未来城c1119（群光广场）',
#   'allCommentNum': 283,
#   'avgPrice': 45,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42960793,
#   'title': '白熊甜品店（街道口店）'},
#  {'address': '江汉区民意三路与民主一街交汇处7号附9号',
#   'allCommentNum': 113,
#   'avgPrice': 9,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5145613,
#   'title': '梅花王蛋糕（民意三路店）'},
#  {'address': '青山区建设二路2#',
#   'allCommentNum': 588,
#   'avgPrice': 8,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 742810,
#   'title': '华利尔蛋糕'},
#  {'address': '黄陂区巨龙大道盘龙城08经典28号临街商铺A13号',
#   'allCommentNum': 397,
#   'avgPrice': 10,
#   'avgScore': 3.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40176872,
#   'title': '名嘉蛋糕（08经典店）'},
#  {'address': '蔡甸区宁康路58号湘隆时代广场A区10栋10号',
#   'allCommentNum': 1588,
#   'avgPrice': 20,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 742113,
#   'title': '台北蛋糕（湘隆店）'},
#  {'address': '东西湖区沿海赛洛城二期B10-7（汇然纯水果大卖场）',
#   'allCommentNum': 391,
#   'avgPrice': 10,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5653936,
#   'title': '梅花王蛋糕（赛洛城店）'},
#  {'address': '江汉区常青街银河里66号欧亚达国际广场汉口店B1层',
#   'allCommentNum': 396,
#   'avgPrice': 12,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41395729,
#   'title': '柠檬王子（欧亚达国际广场汉口店）'},
#  {'address': '汉阳区龙阳大道58号人信汇商场B1楼',
#   'allCommentNum': 1778,
#   'avgPrice': 7,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4278889,
#   'title': '一品豆花（人信汇商场店）'},
#  {'address': '江夏区四贤路县医院北',
#   'allCommentNum': 164,
#   'avgPrice': 58,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41063503,
#   'title': '江申蛋糕（四贤路总店）'},
#  {'address': '洪山区珞喻路肯德基隔壁（鲁巷广场外）',
#   'allCommentNum': 1651,
#   'avgPrice': 25,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6166473,
#   'title': '答案茶（光谷店）'},
#  {'address': '洪山区关山大道光谷天地F区一层G-F-026号',
#   'allCommentNum': 444,
#   'avgPrice': 23,
#   'avgScore': 3.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4160549,
#   'title': '榴莲一品（光谷天地店）'},
#  {'address': '洪山区光谷步行街四楼火星美食城',
#   'allCommentNum': 1113,
#   'avgPrice': 9,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42268636,
#   'title': '柠檬王子（天空城店）'},
#  {'address': '黄陂区板桥大道147号',
#   'allCommentNum': 435,
#   'avgPrice': 0,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1899318,
#   'title': '王中王蛋糕（板桥大道店）'},
#  {'address': '汉阳区汉阳大街70附2号',
#   'allCommentNum': 802,
#   'avgPrice': 10,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4496385,
#   'title': '蛋糕心语（蔡甸一店）'},
#  {'address': '洪山区虎泉街64号',
#   'allCommentNum': 186,
#   'avgPrice': 240,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 50580593,
#   'title': '一菲蛋糕坊'},
#  {'address': '青山区康乐路11附4号（喜结良缘婚礼馆西行20米）',
#   'allCommentNum': 147,
#   'avgPrice': 18,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4099477,
#   'title': '梅花西饼（康乐路店）'},
#  {'address': '武昌区积玉桥万达广场13号楼616号（徐东销品茂正左侧）',
#   'allCommentNum': 5211,
#   'avgPrice': 25,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5742151,
#   'title': '茗记甜品（徐东店）'},
#  {'address': '江夏区兴新街76号（江夏第一初级中学对面中国银行旁）',
#   'allCommentNum': 524,
#   'avgPrice': 37,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4431076,
#   'title': '金苹果蛋糕（一初老街店）'},
#  {'address': '洪山区珞喻路998号光谷国际广场（中心花园第A幢A层099号房，近鲁巷广场，光谷大洋百货）',
#   'allCommentNum': 2045,
#   'avgPrice': 0,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42522908,
#   'title': '幸福时光蛋糕（光谷广场店）'},
#  {'address': '江汉区花楼街悦荟（原万达）广场B座81号（江汉路花楼街悦荟广场B座3号门）',
#   'allCommentNum': 83,
#   'avgPrice': 40,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42245965,
#   'title': 'AiCo艾可私人订制蛋糕（悦荟广场店）'},
#  {'address': '硚口区解放大道967号（宝丰路工贸家电对面）',
#   'allCommentNum': 148,
#   'avgPrice': 0,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 741575,
#   'title': '梅花王蛋糕（宝仪店）'},
#  {'address': '蔡甸区东风大道奥林花园小区商铺1-17（金色港湾车站旁）',
#   'allCommentNum': 167,
#   'avgPrice': 0,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6759947,
#   'title': '欧麦蛋糕（奥林花园店）'},
#  {'address': '武昌区彭刘杨西路汉飞逛逛街3号楼3119室（司门口天桥美特斯邦威旁边）民主路司门口天桥美特斯邦威旁（快捷酒店旁）',
#   'allCommentNum': 95,
#   'avgPrice': 9,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41349174,
#   'title': '吾饮良品'},
#  {'address': '青山区康乐路11附4号（喜结良缘婚礼馆西行20米）',
#   'allCommentNum': 147,
#   'avgPrice': 18,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4099477,
#   'title': '梅花西饼（康乐路店）'},
#  {'address': '江夏区四贤路县医院北',
#   'allCommentNum': 164,
#   'avgPrice': 58,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41063503,
#   'title': '江申蛋糕（四贤路总店）'},
#  {'address': '洪山区野芷湖西路马湖商业街特1号Idrink吾饮良品',
#   'allCommentNum': 142,
#   'avgPrice': 10,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41165800,
#   'title': '吾饮良品（保利心语店）'},
#  {'address': '东西湖区东吴家山小区10栋1单元102室（吴祁街63号）',
#   'allCommentNum': 405,
#   'avgPrice': 136,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5788720,
#   'title': '梅花王蛋糕（吴祁街店）'},
#  {'address': '硚口区解放大道457号东北（十七中学旁）',
#   'allCommentNum': 242,
#   'avgPrice': 0,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5069885,
#   'title': '梅花王蛋糕'},
#  {'address': '洪山区建设一路钢洲花园天桥旁（九洲国际正对面）',
#   'allCommentNum': 176,
#   'avgPrice': 11,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4294914,
#   'title': '盛世金威蛋糕（钢洲花园店）'},
#  {'address': '洪山区红花路大花岭小区D5栋',
#   'allCommentNum': 345,
#   'avgPrice': 15,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4277939,
#   'title': '好来西烘焙（大花岭店）'},
#  {'address': '洪山区珞喻路726号世界城广场B1层',
#   'allCommentNum': 483,
#   'avgPrice': 17,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 51469339,
#   'title': '水果巴士（世界城广场店）'},
#  {'address': '蔡甸区江汉大学路口2号门（博学路三角湖路交叉口东南角）',
#   'allCommentNum': 401,
#   'avgPrice': 9,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6631525,
#   'title': '吾饮良品（江大2号门店）'},
#  {'address': '江汉区新华路420附1号',
#   'allCommentNum': 75,
#   'avgPrice': 0,
#   'avgScore': 3.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6327102,
#   'title': '斐丽蛋糕'},
#  {'address': '黄陂区巨龙大道盘龙城F空港中心城1-3号（中国国际航空公司斜对面）',
#   'allCommentNum': 139,
#   'avgPrice': 20,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5626173,
#   'title': '友芝友'},
#  {'address': '蔡甸区江汉大学路口2号门（博学路三角湖路交叉口东南角）',
#   'allCommentNum': 401,
#   'avgPrice': 9,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6631525,
#   'title': '吾饮良品（江大2号门店）'},
#  {'address': '洪山区工大路13号（近豆豆智慧旅馆连锁）',
#   'allCommentNum': 138,
#   'avgPrice': 7,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1897091,
#   'title': '天天鲜蛋糕（理工店）'},
#  {'address': '汉南区中心城区汉南大道362号（近客运站）',
#   'allCommentNum': 284,
#   'avgPrice': 0,
#   'avgScore': 3.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 2730735,
#   'title': '爱可西饼（汉南店）'},
#  {'address': '硚口区解放大道967号（宝丰路工贸家电对面）',
#   'allCommentNum': 148,
#   'avgPrice': 0,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 741575,
#   'title': '梅花王蛋糕（宝仪店）'},
#  {'address': '洪山区南湖李纸路22号拉德芳斯美食购物街负一楼仟佰客超市内（华科武昌分校对面/湖北工业大学对面）',
#   'allCommentNum': 220,
#   'avgPrice': 8,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40063512,
#   'title': '甜心芝语'},
#  {'address': '青山区建设二路2#',
#   'allCommentNum': 588,
#   'avgPrice': 8,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 742810,
#   'title': '华利尔蛋糕'},
#  {'address': '洪山区红花路大花岭小区D5栋',
#   'allCommentNum': 345,
#   'avgPrice': 15,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4277939,
#   'title': '好来西烘焙（大花岭店）'},
#  {'address': '黄陂区武湖街道武湖正街41号东北（武湖正街红绿灯路口）',
#   'allCommentNum': 96,
#   'avgPrice': 27,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4923672,
#   'title': '悠优西饼屋'},
#  {'address': '江汉区常青五路35号',
#   'allCommentNum': 42,
#   'avgPrice': 31,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6478403,
#   'title': '雪祺蛋糕'},
#  {'address': '汉阳区鹦鹉大道446号金桥港湾花园（杨泗庙公交站）',
#   'allCommentNum': 172,
#   'avgPrice': 10,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4020652,
#   'title': '仟禧蛋糕（杨泗庙店）'},
#  {'address': '洪山区虎泉街卓豹路366号（光谷地铁站）',
#   'allCommentNum': 251,
#   'avgPrice': 0,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41807942,
#   'title': '瑞丰蛋糕（武汉工程大学店）'},
#  {'address': '洪山区雄楚大道666号商贸学院后街（杨家湾沃尔玛）',
#   'allCommentNum': 209,
#   'avgPrice': 18,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4200990,
#   'title': '瑞丰蛋糕（杨家湾店）'},
#  {'address': '洪山区恒安路成功花园A区门口',
#   'allCommentNum': 75,
#   'avgPrice': 10,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6046402,
#   'title': '卡布基诺蛋糕'},
#  {'address': '洪山区南湖恒安路与瑞安路交叉口工商银行隔壁（中百超市旁）',
#   'allCommentNum': 457,
#   'avgPrice': 120,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 2542788,
#   'title': '奇米克蛋糕店（南湖温馨苑店）'},
#  {'address': '洪山区园艺文化街红霞名苑小区12-2-301',
#   'allCommentNum': 37,
#   'avgPrice': 0,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6424201,
#   'title': '思味特手工烘培坊'},
#  {'address': '黄陂区盘龙城刘店汉北康城1栋16号',
#   'allCommentNum': 125,
#   'avgPrice': 0,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4955916,
#   'title': '优乐滋蛋糕'},
#  {'address': '洪山区珞南街珞瑜路35号珞珈创意城LG层LG006、LG007号',
#   'allCommentNum': 1,
#   'avgPrice': 36,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4594402,
#   'title': '爱茜茜里（武汉银泰）'},
#  {'address': '黄陂区横店大道今古城商业街1区1楼24号商铺',
#   'allCommentNum': 18,
#   'avgPrice': 12,
#   'avgScore': 3.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42450494,
#   'title': '筷尚客'},
#  {'address': '洪山区中南财经政法大学（堂附近）',
#   'allCommentNum': 44,
#   'avgPrice': 0,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6510966,
#   'title': '筱雅蛋糕'},
#  {'address': '江岸区后湖街兴业南路新地东方花都A区7号',
#   'allCommentNum': 31,
#   'avgPrice': 17,
#   'avgScore': 3.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6017838,
#   'title': '友芝友蛋糕店'},
#  {'address': '硚口区解放大道387号4层（轻轨1号线宗关站）',
#   'allCommentNum': 33,
#   'avgPrice': 15,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4886232,
#   'title': '酷果乐（南国西汇城市广场店）'},
#  {'address': '蔡甸区芳草路观澜御苑G2栋',
#   'allCommentNum': 10,
#   'avgPrice': 33,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4327736,
#   'title': '大益茶御茗茶庄'},
#  {'address': '武昌区徐东二路欧洲花园十栋四单元402室（近新世界百货）',
#   'allCommentNum': 93,
#   'avgPrice': 30,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 747877,
#   'title': '曼罗曼蒂手工巧克力蛋糕坊（徐东店）'},
#  {'address': '洪山区珞瑜路35号银泰创意城负一楼019号',
#   'allCommentNum': 4444,
#   'avgPrice': 10,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 93846814,
#   'title': '广隆蛋挞王（银泰创意城店）'},
#  {'address': '洪山区华中科技大学武昌分校对面拉德芳斯B区一楼109号',
#   'allCommentNum': 4,
#   'avgPrice': 23,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42699055,
#   'title': '嘉士'},
#  {'address': '青山区和平大道1040号武汉理工大学余家头校区海虹公寓1层4号',
#   'allCommentNum': 0,
#   'avgPrice': 3,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40885720,
#   'title': '四季花（理工店）'},
#  {'address': '江夏区金桂街大花岭小区A8栋',
#   'allCommentNum': 0,
#   'avgPrice': 0,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4845655,
#   'title': '康心蛋糕店（大花岭店）'},
#  {'address': '江汉区自治街燕马新村12栋52号（小精灵幼儿园旁）',
#   'allCommentNum': 1,
#   'avgPrice': 8,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41760366,
#   'title': '天冰冰淇淋（燕马新村店）'},
#  {'address': '江汉区金墩路8号陕西大厦1楼',
#   'allCommentNum': 89,
#   'avgPrice': 24,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 2753177,
#   'title': '彼岸咖啡'},
#  {'address': '武昌区中北路普提金商务中心负一楼（电梯地下一层入口处）',
#   'allCommentNum': 6,
#   'avgPrice': 11,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6250376,
#   'title': '豆花妈妈（岳家嘴店）'},
#  {'address': '江汉区解放大道武展东路崇光sogo写字楼A座2408号（2号线中山公园地铁B2出口）',
#   'allCommentNum': 28,
#   'avgPrice': 205,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41512562,
#   'title': '半暖时光翻糖蛋糕&定制甜品台（中山公园店）'},
#  {'address': '蔡甸区东风大道111号经开金街g131',
#   'allCommentNum': 7,
#   'avgPrice': 8,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6157233,
#   'title': '鲜饮时尚'},
#  {'address': '江夏区凤凰花园二期商业街170号',
#   'allCommentNum': 0,
#   'avgPrice': 0,
#   'avgScore': 3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40842064,
#   'title': '优果汇'},
#  {'address': '洪山区南湖大道光谷天地F区',
#   'allCommentNum': 807,
#   'avgPrice': 46,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42972836,
#   'title': '哥瑞特蛋糕（光谷天地店）'},
#  {'address': '武昌区白沙洲大道张家湾建材路34号',
#   'allCommentNum': 38,
#   'avgPrice': 0,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42823572,
#   'title': '心语蛋糕'},
#  {'address': '江汉区常飞街40号楚天都市金园6栋7号门面',
#   'allCommentNum': 1227,
#   'avgPrice': 111,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40763348,
#   'title': '蜜时cake'},
#  {'address': '江夏区杨桥湖大道梁山头商业街第三排卡恩电脑旁',
#   'allCommentNum': 39,
#   'avgPrice': 12,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42462650,
#   'title': '四季花奶茶'},
#  {'address': '江夏区高新四路葛洲坝太阳城1栋504室',
#   'allCommentNum': 1877,
#   'avgPrice': 112,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 88883526,
#   'title': '幸福西饼蛋糕（高新四路店）'},
#  {'address': '江岸区江汉路步行街ATM潮流百货（京汉大道与崇仁路交汇处）',
#   'allCommentNum': 19,
#   'avgPrice': 10,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42606634,
#   'title': '阿2时尚茶饮'},
#  {'address': '汉阳区钟家村闽东国际3b栋1120室（地铁a出口金隆豪泰酒店上来）',
#   'allCommentNum': 832,
#   'avgPrice': 65,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40603916,
#   'title': 'misu,cake手工烘焙坊（闽东国际城店）'},
#  {'address': '江岸区三阳路华商悦购超市（三阳路轻轨站）',
#   'allCommentNum': 407,
#   'avgPrice': 219,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40012221,
#   'title': 'Angel千惠蛋糕私家定制'},
#  {'address': '武昌区徐东路徐东平价正门旁',
#   'allCommentNum': 2864,
#   'avgPrice': 28,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 748727,
#   'title': '皇冠蛋糕（徐东平价店）'},
#  {'address': '青山区和平大道819号奥山世纪城B1层',
#   'allCommentNum': 3014,
#   'avgPrice': 12,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41132609,
#   'title': '蛋挞皇后（奥山世纪城店）'},
#  {'address': '武昌区中南路街办事处丁字桥路68号中百仓储1楼',
#   'allCommentNum': 473,
#   'avgPrice': 52,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 77284020,
#   'title': '哥瑞特蛋糕（丁字桥店）'},
#  {'address': '武昌区团结村福星惠誉国际城K2地块第4幢/单元2层1-3号',
#   'allCommentNum': 2751,
#   'avgPrice': 49,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4160898,
#   'title': 'CaffeBene咖啡陪你（福客茂店）'},
#  {'address': '武昌区中山路昙华林202号南国昙华林1层（螃蟹岬公交站）',
#   'allCommentNum': 0,
#   'avgPrice': 22,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 118422778,
#   'title': '酷姆思酸奶冰淇淋（南国昙华林店）'},
#  {'address': '洪山区光谷步行街1期与西班牙风情街连接处（近阿依莲和三福，中影天河影城正下方）',
#   'allCommentNum': 6227,
#   'avgPrice': 10,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1898549,
#   'title': '悸动烧仙草（光谷旗舰店）'},
#  {'address': '青山区和平大道众圆广场一楼1007A',
#   'allCommentNum': 2245,
#   'avgPrice': 28,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4491757,
#   'title': 'ZOOCOFFEE西餐厅'},
#  {'address': '江岸区中山大道1556号（武汉二中对面）',
#   'allCommentNum': 1572,
#   'avgPrice': 19,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 750326,
#   'title': '爱么泡芙（二中店）'},
#  {'address': '江汉区解放大道557号中山广场写字楼1925室（地铁2号线中山公园站E出口）',
#   'allCommentNum': 867,
#   'avgPrice': 22,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5326134,
#   'title': '境自在咖啡书店'},
#  {'address': '江汉区雪松路41号（近万松园路老街烧烤斜对面）',
#   'allCommentNum': 1736,
#   'avgPrice': 21,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4611291,
#   'title': '榴莲飘香（万松园店）'},
#  {'address': '洪山区关山大道519号光谷天地1层（老村长对面）',
#   'allCommentNum': 1054,
#   'avgPrice': 7,
#   'avgScore': 3.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5508006,
#   'title': '一品豆花（光谷天地店）'},
#  {'address': '洪山区街道口武汉理工大学马房山校区东院大门口（马房山通道转盘旁）',
#   'allCommentNum': 1539,
#   'avgPrice': 21,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4410093,
#   'title': '百读咖啡书社'},
#  {'address': '武昌区珞狮路武汉大学工学部68舍一楼',
#   'allCommentNum': 1371,
#   'avgPrice': 10,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5305995,
#   'title': 'TeaZone茶语寿司'},
#  {'address': '青山区和平大道建设二路众圆广场2楼',
#   'allCommentNum': 2116,
#   'avgPrice': 13,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6763413,
#   'title': '壹品豆花（众圆广场店）'},
#  {'address': '武昌区徐东大街18号武汉销品茂5层G5036号',
#   'allCommentNum': 1632,
#   'avgPrice': 14,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42789886,
#   'title': '御可贡茶（销品茂店）'},
#  {'address': '武昌区水果湖街东湖路105号万达嘉华酒店内1楼左侧（放鹰桥旁）',
#   'allCommentNum': 313,
#   'avgPrice': 111,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4974745,
#   'title': '富力万达嘉华酒店·大堂酒廊'},
#  {'address': '蔡甸区宁康路58号湘隆时代广场A区9栋13号',
#   'allCommentNum': 131,
#   'avgPrice': 10,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1898989,
#   'title': '泡沫剧茶（宁康路店）'},
#  {'address': '汉阳区汉阳大街78附1号',
#   'allCommentNum': 933,
#   'avgPrice': 6,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40331860,
#   'title': '尚饮港'},
#  {'address': '江汉区武商广场摩尔城7F（武商摩尔国际电影城旁）',
#   'allCommentNum': 1463,
#   'avgPrice': 27,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1894083,
#   'title': 'DQ（武商摩尔店）'},
#  {'address': '江汉区解放大道690号（武汉国际广场购物中心B1层）',
#   'allCommentNum': 430,
#   'avgPrice': 14,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1029385,
#   'title': '丸丸山糕坊（武汉国际广场店）'},
#  {'address': '洪山区珞喻路蔡林记隔壁',
#   'allCommentNum': 663,
#   'avgPrice': 9,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4866404,
#   'title': '吾饮良品（汇通大厦店）'},
#  {'address': '洪山区光谷广场步行街加州阳光4栋603',
#   'allCommentNum': 39,
#   'avgPrice': 0,
#   'avgScore': 3.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 162186840,
#   'title': '生日礼物·爱四分之一蛋糕'},
#  {'address': '汉阳区汉阳大道润帝嘉园沿街商铺、汉阳十里铺57号',
#   'allCommentNum': 1257,
#   'avgPrice': 50,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 94814610,
#   'title': '储缘蛋糕（十里铺店）'},
#  {'address': '武昌区武珞路五巷46号凯乐花园7栋1层4号商铺',
#   'allCommentNum': 56,
#   'avgPrice': 0,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 163198403,
#   'title': '味佰思CAKE（--武昌店）'},
#  {'address': '武昌区解放路365号界立方商场一楼1004号商铺',
#   'allCommentNum': 122,
#   'avgPrice': 37,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 109156267,
#   'title': '惠子烘焙'},
#  {'address': '洪山区和平街道北洋桥路菁华园大门口（景胜花园南）',
#   'allCommentNum': 5,
#   'avgPrice': 25,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 158707029,
#   'title': '金威蛋糕（菁华园店）'},
#  {'address': '洪山区雄楚大道雄楚一号商6栋s611商铺（贵哥卤肉卷旁）',
#   'allCommentNum': 459,
#   'avgPrice': 9,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41769641,
#   'title': '吾饮良品（雄楚一号店）'},
#  {'address': '黄陂区横店小学新大门旁（意尔康隔壁）',
#   'allCommentNum': 353,
#   'avgPrice': 0,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6001393,
#   'title': '艾美斯秀饼坊（小学店）'},
#  {'address': '江夏区兴新街江夏大道交口西行40米路南',
#   'allCommentNum': 258,
#   'avgPrice': 33,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4426900,
#   'title': '天使咖啡（兴新街店）'},
#  {'address': '武昌区中北路109号凯德广场1818B1层12号',
#   'allCommentNum': 161,
#   'avgPrice': 18,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 67237432,
#   'title': '樱花糕坊（凯德广场1818店）'},
#  {'address': '洪山区新路村1号（银河学院对面）',
#   'allCommentNum': 309,
#   'avgPrice': 15,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4744254,
#   'title': '好来西烘焙（银河学院店）'},
#  {'address': '洪山区青菱街红霞村福星惠誉东澜岸43栋1-2层10号（友间网吧）',
#   'allCommentNum': 248,
#   'avgPrice': 23,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4744872,
#   'title': '金麦坊蛋糕'},
#  {'address': '武昌区徐东大街18号销品茂5层（大食汇对面）',
#   'allCommentNum': 1020,
#   'avgPrice': 12,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1474395,
#   'title': '哈米泡芙·HammyPuff（销品茂店）'},
#  {'address': '青山区工业三路37附17号',
#   'allCommentNum': 277,
#   'avgPrice': 22,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6453518,
#   'title': '台北蛋糕（工业三路店）'},
#  {'address': '东西湖区金银潭大道1号永旺梦乐城3层',
#   'allCommentNum': 633,
#   'avgPrice': 65,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40587468,
#   'title': '约你蛋糕（金银潭永旺店）'},
#  {'address': '东西湖区田园街407号（城管局对面）',
#   'allCommentNum': 433,
#   'avgPrice': 25,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 2752090,
#   'title': '雅轩蛋糕（田园总店）'},
#  {'address': '江汉区江汉路步行街61号园缘圆1楼（近好乐迪）',
#   'allCommentNum': 728,
#   'avgPrice': 10,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 746870,
#   'title': 'A咖茶园时尚饮品（江汉店）'},
#  {'address': '武昌区欢乐大道华侨城东方里商业街S2-A商铺（地铁4号线铁机路站；581、534、777、566、782公交站）',
#   'allCommentNum': 181,
#   'avgPrice': 28,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42768249,
#   'title': '枕流茶行'},
#  {'address': '硚口区中山大道238号凯德广场负一楼',
#   'allCommentNum': 1365,
#   'avgPrice': 13,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5055057,
#   'title': 'isit juice纯鲜榨果汁（武胜凯德店）'},
#  {'address': '江岸区建设大道700号香格里拉大酒店1楼\xa0',
#   'allCommentNum': 1703,
#   'avgPrice': 111,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 2429532,
#   'title': '香苑·自助餐（香格里拉大酒店）'},
#  {'address': '洪山区光谷步行街九号食堂内',
#   'allCommentNum': 122,
#   'avgPrice': 10,
#   'avgScore': 3.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41031609,
#   'title': '绿色甜蜜美食坊'},
#  {'address': '武昌区友谊大道19号武汉友谊国际酒店4楼',
#   'allCommentNum': 134,
#   'avgPrice': 83,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40694572,
#   'title': '友谊国际酒店中餐厅'},
#  {'address': '武昌区水果湖步行街15号（中百仓储水果湖店）',
#   'allCommentNum': 141,
#   'avgPrice': 12,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 742733,
#   'title': '麦香城蛋糕（水果湖路店）'},
#  {'address': '蔡甸区汉阳大街欧尚超市电梯入口附近',
#   'allCommentNum': 556,
#   'avgPrice': 7,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 65560737,
#   'title': '尚饮港（欧尚店）'},
#  {'address': '江夏区庙山武昌理工学院西区四食堂对面',
#   'allCommentNum': 117,
#   'avgPrice': 12,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6262749,
#   'title': '麦香城蛋糕（武昌理工大学店）'},
#  {'address': '江夏区藏龙岛杨乔湖大道湖北经济学院北大门商业服务中心一楼1F-106号',
#   'allCommentNum': 139,
#   'avgPrice': 10,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5328134,
#   'title': '益丰坊'},
#  {'address': '江汉区中山大道818号佳丽广场B1楼HAPPY站台070号(近万达广场 地铁2号线江汉路站)',
#   'allCommentNum': 114,
#   'avgPrice': 12,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1158290,
#   'title': '快乐柠檬（HAPPY站台店）'},
#  {'address': '新洲区中心城区衡州大街摩尔城一楼门口',
#   'allCommentNum': 427,
#   'avgPrice': 26,
#   'avgScore': 3.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 62799206,
#   'title': '芙蕾优焙（新洲摩尔城店）'},
#  {'address': '洪山区南湖南路1号中南财经政法大学清水园小区6栋10号',
#   'allCommentNum': 43,
#   'avgPrice': 25,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1898683,
#   'title': '浮光咖啡馆'},
#  {'address': '武昌区东亭路湖北纺织建筑设计院1-3号梨园大酒店对面',
#   'allCommentNum': 188,
#   'avgPrice': 15,
#   'avgScore': 3.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 2558638,
#   'title': '卡文.艾美（徐东店）'},
#  {'address': '东西湖区一清路竹叶海嘉园168号附19号（阁爵钱柜KTV旁）',
#   'allCommentNum': 102,
#   'avgPrice': 14,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5744728,
#   'title': '格瑞提拉米苏（一清路店）'},
#  {'address': '洪山区珞瑜路20号（武昌新世界百货对面阜华大厦一楼）',
#   'allCommentNum': 1356,
#   'avgPrice': 73,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 82295,
#   'title': '元祖食品（街道口店）'},
#  {'address': '江岸区解放大道堤角小区星园二期18号商网',
#   'allCommentNum': 87,
#   'avgPrice': 10,
#   'avgScore': 3.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1893613,
#   'title': '雪莲蛋糕'},
#  {'address': '武昌区中山路大东门爱尔眼科医院旁',
#   'allCommentNum': 953,
#   'avgPrice': 0,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 67090468,
#   'title': '麦客蛋糕（大东门店）'},
#  {'address': '江夏区江夏大道16号武昌理工学院皇家蛋糕店',
#   'allCommentNum': 131,
#   'avgPrice': 25,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4766374,
#   'title': '皇家蛋糕（庙山店）'},
#  {'address': '洪山区文化大道大桥新区红旗小区9号门面（长江工程职业学院旁）',
#   'allCommentNum': 132,
#   'avgPrice': 15,
#   'avgScore': 3.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6282263,
#   'title': '吉麦村西饼（长江工程职业学院店）'},
#  {'address': '江岸区洞庭街124号（市妇联大厦对面）',
#   'allCommentNum': 121,
#   'avgPrice': 63,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41172319,
#   'title': '94咖啡轻食餐吧'},
#  {'address': '洪山区富安街59号华锦花园606栋1单元1层商铺',
#   'allCommentNum': 18,
#   'avgPrice': 20,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42097457,
#   'title': '多彩蛋糕店'},
#  {'address': '汉阳区康达街10号万科汉阳国际B地块1栋1层商2（万科汉阳国际B区2号门）',
#   'allCommentNum': 127,
#   'avgPrice': 14,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 50967131,
#   'title': '小西鲜生'},
#  {'address': '江汉区江汉北路40号（九运大厦旁）',
#   'allCommentNum': 30,
#   'avgPrice': 9,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 747670,
#   'title': '乐麦烘焙'},
#  {'address': '江岸区台北路215号（天门墩公交车站附近）',
#   'allCommentNum': 125,
#   'avgPrice': 12,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 741656,
#   'title': '嘉仕麦蛋糕'},
#  {'address': '武昌区粮道街41号（粮道街中学对面）',
#   'allCommentNum': 142,
#   'avgPrice': 16,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4451807,
#   'title': '圣玛俐烘焙世家'},
#  {'address': '阳逻街区阳光大道283号（阳逻大转盘）',
#   'allCommentNum': 132,
#   'avgPrice': 18,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41847543,
#   'title': '爱心优焙（转盘店）'},
#  {'address': '黄陂区黄陂大道387号黄陂广场2层（清潭洞自助烤肉旁）',
#   'allCommentNum': 3208,
#   'avgPrice': 5,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1899373,
#   'title': '优咖饮品（黄陂广场店）'},
#  {'address': '江汉区中山大道818号佳丽广场B1楼HAPPY站台C010号（民生路口 地铁2号线江汉路站）',
#   'allCommentNum': 118,
#   'avgPrice': 15,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 766285,
#   'title': '摩娅咖啡（HAPPY站台店）'},
#  {'address': '洪山区理工大学升升公寓食堂门口',
#   'allCommentNum': 15,
#   'avgPrice': 45,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6834598,
#   'title': '美欣西饼屋（理工大学店）'},
#  {'address': '黄陂区汉黄路盘龙城刘古塘村综合楼205号（刘店龙辰丽湾小区，刘店农贸市场中门）',
#   'allCommentNum': 14,
#   'avgPrice': 6,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42136280,
#   'title': '名嘉蛋糕（龙辰丽湾店）'},
#  {'address': '武昌区友谊大道396号福客茂1层',
#   'allCommentNum': 695,
#   'avgPrice': 11,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5885236,
#   'title': '吾饮良品（福客茂店）'},
#  {'address': '江汉区汉口建设大道707号锦江国际大酒店1楼（近建设银行）',
#   'allCommentNum': 63,
#   'avgPrice': 71,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 765342,
#   'title': '锦江国际大堂吧'},
#  {'address': '武昌区武汉大学工学部网球场二号门面（阿里ba吧对面）',
#   'allCommentNum': 35,
#   'avgPrice': 11,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1896980,
#   'title': '润泽蛋糕店'},
#  {'address': '武昌区昙华林马道门4号',
#   'allCommentNum': 128,
#   'avgPrice': 33,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4628838,
#   'title': '贝总西餐吧（昙华林店）'},
#  {'address': '洪山区保利心语3期生鲜市场西外19号',
#   'allCommentNum': 15,
#   'avgPrice': 15,
#   'avgScore': 3.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42036061,
#   'title': '采烘蛋糕'},
#  {'address': '江岸区黎黄陂路24号1楼（新源大厦旁）',
#   'allCommentNum': 6,
#   'avgPrice': 33,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4181587,
#   'title': 'MILA蜜蜡'},
#  {'address': '武昌区中北路109号凯德1818B1-24',
#   'allCommentNum': 260,
#   'avgPrice': 20,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 63945069,
#   'title': 'Hurom Juice 惠人芳（凯德1818店）'},
#  {'address': '洪山区黄家湖西路福星惠誉东澜岸广场2号楼2-2-7号',
#   'allCommentNum': 182,
#   'avgPrice': 7,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4557059,
#   'title': '罗蒂爸爸（东澜岸店）'},
#  {'address': '洪山区珞珈山武大路66号(肯德基斜对面)',
#   'allCommentNum': 331,
#   'avgPrice': 10,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4107420,
#   'title': '吾饮良品（武大正门店）'},
#  {'address': '洪山区洪山区珞瑜路726号102-104号',
#   'allCommentNum': 206,
#   'avgPrice': 115,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4876686,
#   'title': '武汉华美达光谷大酒店·大堂酒廊'},
#  {'address': '洪山区街道口新世界百货5楼',
#   'allCommentNum': 69,
#   'avgPrice': 30,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 77425485,
#   'title': '苏蜜Cake蛋糕甜品（街道口店）'},
#  {'address': '洪山区东湖开发区大学园路特1号（万科城市花园对面）关山大道与三环交汇处立交旁',
#   'allCommentNum': 58,
#   'avgPrice': 97,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 2792789,
#   'title': '皇家格雷斯大酒店大堂吧'},
#  {'address': '洪山区武珞路街道口地铁A出口',
#   'allCommentNum': 36,
#   'avgPrice': 18,
#   'avgScore': 3.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 66121745,
#   'title': '志宏宫廷糕点（街道口店）'},
#  {'address': '洪山区大花岭小区E1栋',
#   'allCommentNum': 579,
#   'avgPrice': 0,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 60580533,
#   'title': '吉麦村西饼（金煌店）'},
#  {'address': '黄陂区黄陂大道387号黄陂广场2层',
#   'allCommentNum': 2434,
#   'avgPrice': 8,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6376663,
#   'title': '雪豆花（黄陂广场店）'},
#  {'address': '黄陂区前川大道77号',
#   'allCommentNum': 26,
#   'avgPrice': 0,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1899316,
#   'title': '金苹果西饼屋（前川大道店）'},
#  {'address': '黄陂区百秀街2附6号老车站进站口旁',
#   'allCommentNum': 23,
#   'avgPrice': 10,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 51828148,
#   'title': '吾饮良品（老车站店）'},
#  {'address': '洪山区岭南新村2号铺(心怡缘网吧旁)',
#   'allCommentNum': 38,
#   'avgPrice': 35,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42391789,
#   'title': '金瑞蛋糕'},
#  {'address': '江汉区京汉大道661号江城华庭翠景阁B座502',
#   'allCommentNum': 1,
#   'avgPrice': 158,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 68422857,
#   'title': '丫丫宝贝diy蛋糕烘焙坊'},
#  {'address': '汉南区中心城区纱帽街汪杨郭2栋2单元1层3室（原城关小学西侧）',
#   'allCommentNum': 191,
#   'avgPrice': 0,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6112775,
#   'title': 'One day 全天烘焙（汉南店）'},
#  {'address': '江汉区解放大道690号武汉国际广场C座2楼天桥进口处(无印良品旁)',
#   'allCommentNum': 11,
#   'avgPrice': 72,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6206599,
#   'title': 'Annvita Tea Room 安薇塔（国际广场店）'},
#  {'address': '洪山区黄家湖大学城丽水南路东澜岸广场1号楼917（进云莱酒店大厅上9楼）',
#   'allCommentNum': 226,
#   'avgPrice': 17,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5650681,
#   'title': '七里香DIY蛋糕烘焙（东澜岸店）'},
#  {'address': '洪山区东湖新技术开发区熊家咀八一花园E1-109号商铺',
#   'allCommentNum': 519,
#   'avgPrice': 0,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 51995449,
#   'title': '帝诺蛋糕（八一花园店）'},
#  {'address': '江夏区工程大学流芳校区对面泰塑公寓旁（西门炊牛旁）',
#   'allCommentNum': 108,
#   'avgPrice': 0,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 68575022,
#   'title': '大师傅蛋糕（工程大学店）'},
#  {'address': '江汉区唐家墩路5-1号万达广场万达D006',
#   'allCommentNum': 21,
#   'avgPrice': 42,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5010664,
#   'title': '贝克街·酒咖'},
#  {'address': '武昌区徐东大街120号群星城1层',
#   'allCommentNum': 54,
#   'avgPrice': 34,
#   'avgScore': 3.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6053788,
#   'title': '满记甜品（群星城店）'},
#  {'address': '武昌区紫竹苑公寓1栋（武珞路二巷8号）',
#   'allCommentNum': 6,
#   'avgPrice': 20,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41757123,
#   'title': '星冠蛋糕店'},
#  {'address': '武昌区中北路109号楚河汉街凯德1818广场7楼07-02商铺',
#   'allCommentNum': 72,
#   'avgPrice': 34,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 66310610,
#   'title': '芭缇斯先生新经典法式甜点m.patisserie'},
#  {'address': '武昌区汉街6号J2-2-2（一街区屈原广场）',
#   'allCommentNum': 0,
#   'avgPrice': 65,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1894717,
#   'title': 'Godiva（汉街店）'},
#  {'address': '洪山区东湖开发区民族大道东林外庐22号（近东林外庐）',
#   'allCommentNum': 105,
#   'avgPrice': 0,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 748115,
#   'title': '美味多蛋糕（民族大道店）'},
#  {'address': '洪山区珞喻路726号世界城广场B1层（近生活剧场）',
#   'allCommentNum': 0,
#   'avgPrice': 19,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5872003,
#   'title': '85度C（世界城广场店）'},
#  {'address': '汉阳区大街文波楼（近新闻中心）',
#   'allCommentNum': 47,
#   'avgPrice': 10,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1899257,
#   'title': 'OK!赞'},
#  {'address': '洪山区东湖高新区南新二路佳源花都B座102号',
#   'allCommentNum': 413,
#   'avgPrice': 0,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5377586,
#   'title': '爱可西饼（佳源花都店）'},
#  {'address': '江汉区解放大道690号（武商广场C座B1层）',
#   'allCommentNum': 522,
#   'avgPrice': 46,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 3270732,
#   'title': 'OLD IS NEW 偏爱（国际广场店）'},
#  {'address': '江夏区万科魅力之城12区',
#   'allCommentNum': 2,
#   'avgPrice': 0,
#   'avgScore': 3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4508715,
#   'title': '新语烘焙坊'},
#  {'address': '江夏区阳光大道普安新村31',
#   'allCommentNum': 4,
#   'avgPrice': 30,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 5984395,
#   'title': '天天鲜西饼屋蛋糕'},
#  {'address': '新洲区中心城区新大酒店（红旗街南）',
#   'allCommentNum': 4,
#   'avgPrice': 0,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4979208,
#   'title': '妙麦香面包工坊'},
#  {'address': '武昌区万达汉街广场110号',
#   'allCommentNum': 2,
#   'avgPrice': 82,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1895094,
#   'title': '哈根达斯（汉街店）'},
#  {'address': '武昌区都府堤37号',
#   'allCommentNum': 173,
#   'avgPrice': 27,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 52856535,
#   'title': '榴莲牛奶'},
#  {'address': '武昌区昙华林202号泛悦汇昙华林第1楼1-14号',
#   'allCommentNum': 26,
#   'avgPrice': 20,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 60461823,
#   'title': '猫子商店'},
#  {'address': '江夏区藏龙岛栗庙新村544号',
#   'allCommentNum': 0,
#   'avgPrice': 0,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 62136207,
#   'title': '喵王私家烘焙'},
#  {'address': '硚口区越秀星汇维港一楼',
#   'allCommentNum': 9,
#   'avgPrice': 44,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 69977525,
#   'title': '太平洋咖啡（武汉硚口店）'},
#  {'address': '汉阳区龙阳大道汉商21世纪购物中心3楼',
#   'allCommentNum': 661,
#   'avgPrice': 10,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 50156813,
#   'title': '吾饮良品（汉商3楼店）'},
#  {'address': '洪山区街道口未来城购物公园F1-019号',
#   'allCommentNum': 617,
#   'avgPrice': 15,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 2492860,
#   'title': '芒果酸奶屋（街道口店）'},
#  {'address': '硚口区古田二路天勤花园8栋2号702室',
#   'allCommentNum': 6,
#   'avgPrice': 28,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41927896,
#   'title': '尹小蜜台湾纯手工牛轧糖'},
#  {'address': '东西湖区吴家山竹叶海长宜路1号武汉荟聚中心2层（欧尚超市入口旁）',
#   'allCommentNum': 1197,
#   'avgPrice': 16,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42920925,
#   'title': '伊凡工坊（武汉荟聚中心店）'},
#  {'address': '洪山区南湖大道政院小区40排2号',
#   'allCommentNum': 60,
#   'avgPrice': 6,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 40093545,
#   'title': '蜜乐茶悠（南湖时尚城店）'},
#  {'address': '江汉区范湖路80号泛海喜来登酒店一楼（泛海城市广场）',
#   'allCommentNum': 39,
#   'avgPrice': 80,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 60897121,
#   'title': '喜来登大酒店·大堂吧'},
#  {'address': '汉阳区建桥街办事处拦江路145号',
#   'allCommentNum': 20,
#   'avgPrice': 8,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 67820995,
#   'title': '乐饮'},
#  {'address': '青山区和平大道959号武商众圆广场C区4层（电影院旁）',
#   'allCommentNum': 92,
#   'avgPrice': 20,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 41378248,
#   'title': '芝九草堂（武商众圆广场店）'},
#  {'address': '江汉区江汉路宝丽金b1-2103（万达后中际眼镜上21层）',
#   'allCommentNum': 52,
#   'avgPrice': 32,
#   'avgScore': 3.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 62728413,
#   'title': '喵屋猫咖'},
#  {'address': '东西湖区革新大道482号（神龙生鲜市场）',
#   'allCommentNum': 49,
#   'avgPrice': 20,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6478455,
#   'title': '金冠蛋糕'},
#  {'address': '武昌区武汉水果湖街东湖路138号万达瑞华酒店内',
#   'allCommentNum': 141,
#   'avgPrice': 154,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4761311,
#   'title': '万达瑞华酒店大堂酒廊'},
#  {'address': '黄陂区环形街K2-11号（佳海盘龙广场旁，佳海世纪华联购物中心附近）',
#   'allCommentNum': 60,
#   'avgPrice': 0,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 66312128,
#   'title': '梅花王蛋糕连锁（佳海店）'},
#  {'address': '武昌区丁字桥路朗汇星光68',
#   'allCommentNum': 299,
#   'avgPrice': 60,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 78459817,
#   'title': '很高兴遇见你咖啡吧（郎汇店）'},
#  {'address': '江岸区解放大道1018号循礼门车站处（近武汉剧院）',
#   'allCommentNum': 1015,
#   'avgPrice': 7,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1892677,
#   'title': '奇君甜品（循礼门店）'},
#  {'address': '江岸区姑嫂树路12号南国北都城市广场3层',
#   'allCommentNum': 977,
#   'avgPrice': 13,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6739913,
#   'title': '蜜菓蜜制鲜饮（南国北都城市广场店）'},
#  {'address': '汉阳区王家湾汉商21世纪购物中心四楼秀玉红茶坊门口',
#   'allCommentNum': 224,
#   'avgPrice': 9,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42189835,
#   'title': '吾饮良品（汉商4楼店）'},
#  {'address': '江汉区解放大道342号12-2(世贸大厦旁)',
#   'allCommentNum': 30,
#   'avgPrice': 23,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 31835,
#   'title': '仟吉（武广店）'},
#  {'address': '江汉区解放大道630号新世界酒店1楼',
#   'allCommentNum': 2,
#   'avgPrice': 55,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6317349,
#   'title': '新世界酒店大堂酒廊'},
#  {'address': '江汉区江汉一路和江汉路交叉口西南方向50米',
#   'allCommentNum': 114,
#   'avgPrice': 13,
#   'avgScore': 3.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 1892678,
#   'title': 'CoCo都可（江汉路店）'},
#  {'address': '江夏区杨桥湖大道13号阳光时尚商业街C区2楼',
#   'allCommentNum': 125,
#   'avgPrice': 17,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 42013172,
#   'title': '左耳咖啡'},
#  {'address': '洪山区中国地质大学北区',
#   'allCommentNum': 1,
#   'avgPrice': 0,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6136664,
#   'title': '吾饮良品（地质大学店）'},
#  {'address': '黄陂区武湖农场西环路梅教街130号（宾星宾馆旁边）',
#   'allCommentNum': 32,
#   'avgPrice': 9,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 77407828,
#   'title': '派乐汉堡（武湖店）'},
#  {'address': '黄陂区佳海环行路335号',
#   'allCommentNum': 18,
#   'avgPrice': 10,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 4495358,
#   'title': '裕丰蛋糕坊'},
#  {'address': '汉阳区汉阳大道117号（近汉阳公园）',
#   'allCommentNum': 17,
#   'avgPrice': 12,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 738382,
#   'title': '芝九草堂（汉阳公园店）'},
#  {'address': '洪山区珞瑜路726号光谷步行街光谷德国风情街1层F6159',
#   'allCommentNum': 1406,
#   'avgPrice': 17,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 6071736,
#   'title': '芒果萌（光谷德国风情街店）'},
#  {'address': '江汉区解放大道588号武汉国际广场B座6楼（溜冰场旁）',
#   'allCommentNum': 55,
#   'avgPrice': 70,
#   'avgScore': 4.7,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 52052236,
#   'title': '伊莉维尔（武汉国际广场店）'},
#  {'address': '洪山区洪山区虎泉街卓豹路366号',
#   'allCommentNum': 4,
#   'avgPrice': 0,
#   'avgScore': 3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 67499389,
#   'title': '梦马蛋糕（虎泉街店）'},
#  {'address': '江岸区汉口城市广场5号楼706',
#   'allCommentNum': 13,
# ...
#   'allCommentNum': 83,
#   'avgPrice': 18,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169411331,
#   'title': '爱弥尔鲜饮创作'},
#  {'address': '武昌区武汉大学工学部集贸市场',
#   'allCommentNum': 0,
#   'avgPrice': 11,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169414983,
#   'title': '青沫茶颜'},
#  {'address': '江岸区塔子湖凯信后湖生活广场第1幢10层4号房',
#   'allCommentNum': 3,
#   'avgPrice': 88,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169428200,
#   'title': '爱睿烘焙'},
#  {'address': '洪山区珞珈山路武汉大学正门肯德基隔壁',
#   'allCommentNum': 32,
#   'avgPrice': 15,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169439948,
#   'title': 'TEAMACC茶玛（武大店）'},
#  {'address': '江汉区武商路武商广场东区4楼',
#   'allCommentNum': 104,
#   'avgPrice': 15,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169456613,
#   'title': 'TEAMACC茶玛（武商广场店）'},
#  {'address': '洪山区北一路华中科技大学西十一舍50号门店',
#   'allCommentNum': 91,
#   'avgPrice': 12,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169467332,
#   'title': '春芽拾记'},
#  {'address': '江夏区藏龙北街武汉传媒大学对面',
#   'allCommentNum': 255,
#   'avgPrice': 28,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169469151,
#   'title': '小鹿泡芙（传媒学院店）'},
#  {'address': '武昌区徐东中商平价户部巷门口',
#   'allCommentNum': 62,
#   'avgPrice': 11,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169472553,
#   'title': '吾饮良品（徐东中商平价店）'},
#  {'address': '武昌区白沙洲大道吉祥如意KTV旁',
#   'allCommentNum': 51,
#   'avgPrice': 11,
#   'avgScore': 3.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169489382,
#   'title': '吾饮良品（武泰闸店）'},
#  {'address': '江夏区谭鑫培路万豪世纪天街负一楼',
#   'allCommentNum': 24,
#   'avgPrice': 15,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169508279,
#   'title': '大通冰室（万豪天街店）'},
#  {'address': '江夏区谭鑫培路19号沃尔玛2704F1F0008号',
#   'allCommentNum': 69,
#   'avgPrice': 14,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169509037,
#   'title': '垦丁Q蛋奶茶店'},
#  {'address': '武昌区徐东大街18号',
#   'allCommentNum': 144,
#   'avgPrice': 12,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169514569,
#   'title': '阿姨奶茶（匠心汇店）'},
#  {'address': '武昌区武汉大道徐东匠心汇J12商铺',
#   'allCommentNum': 140,
#   'avgPrice': 15,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169516353,
#   'title': 'TEAMACC茶玛（匠心汇店）'},
#  {'address': '江夏区谭鑫培路17号',
#   'allCommentNum': 6,
#   'avgPrice': 0,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169527534,
#   'title': '泡泡撞茶'},
#  {'address': '洪山区野芷湖西路创意天地04办公楼104-1',
#   'allCommentNum': 2,
#   'avgPrice': 17,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169686732,
#   'title': '茶玛（创意天地店）'},
#  {'address': '武昌区解放路265号实验小学旁',
#   'allCommentNum': 34,
#   'avgPrice': 15,
#   'avgScore': 3.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 169992946,
#   'title': '小确茶'},
#  {'address': '东西湖区海林广场1楼（蔡林记对面）',
#   'allCommentNum': 624,
#   'avgPrice': 12,
#   'avgScore': 3.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 150018630,
#   'title': '广隆蛋挞王（海林广场店）'},
#  {'address': '东西湖区吴中街怡华逸天地1号楼第1层110号商铺',
#   'allCommentNum': 3,
#   'avgPrice': 10,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170000350,
#   'title': '世界茶饮店（吴家山吴中街店）'},
#  {'address': '蔡甸区沌口经开金街体育路111号经开万达金街A区52号',
#   'allCommentNum': 85,
#   'avgPrice': 10,
#   'avgScore': 4.9,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170004010,
#   'title': '答案茶（经开万达店）'},
#  {'address': '江夏区文化大道联投广场一楼',
#   'allCommentNum': 75,
#   'avgPrice': 10,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 116653941,
#   'title': '吾饮良品（联投广场店）'},
#  {'address': '江岸区石桥一路黃浦创立方产业园10栋一楼',
#   'allCommentNum': 19,
#   'avgPrice': 20,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170323779,
#   'title': '窝咖'},
#  {'address': '江汉区天梨豪园C栋102',
#   'allCommentNum': 3,
#   'avgPrice': 60,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170358369,
#   'title': '匠心烘焙蛋糕店'},
#  {'address': '黄陂区盘龙城经济开发区奥莱之星城市广场11栋113号铺',
#   'allCommentNum': 47,
#   'avgPrice': 0,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 118746975,
#   'title': '欧风麦甜蛋糕店'},
#  {'address': '江岸区武汉百步亭世博园201栋1层',
#   'allCommentNum': 2,
#   'avgPrice': 24,
#   'avgScore': 3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170539395,
#   'title': '匆匆烘焙'},
#  {'address': '蔡甸区博学路联投金色港湾一期9号商铺',
#   'allCommentNum': 4,
#   'avgPrice': 28,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170555643,
#   'title': 'D1家'},
#  {'address': '汉阳区招商公园1872项目A地块第2号商业1层10号房',
#   'allCommentNum': 0,
#   'avgPrice': 20,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170557521,
#   'title': '十八度甜（招商公园店）'},
#  {'address': '汉阳区汉阳大道汉商银座E栋1407',
#   'allCommentNum': 7,
#   'avgPrice': 30,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170558513,
#   'title': 'Sweet Dreams甜品定制'},
#  {'address': '洪山区珞瑜路35号银泰创意城7层',
#   'allCommentNum': 13,
#   'avgPrice': 20,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 152168744,
#   'title': '国王城堡里的烘焙工坊（银泰创意城店）'},
#  {'address': '武昌区秦园中路东原时光道A座1楼商铺',
#   'allCommentNum': 24,
#   'avgPrice': 24,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170561893,
#   'title': '千层时光（徐东店）'},
#  {'address': '汉阳区四新北路纽宾凯国际社区蜜城K9地块20号楼三楼30307-2号',
#   'allCommentNum': 44,
#   'avgPrice': 15,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170568688,
#   'title': '榴芒先生'},
#  {'address': '硚口区中山大道238号凯德广场负一楼',
#   'allCommentNum': 308,
#   'avgPrice': 19,
#   'avgScore': 3.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170569900,
#   'title': '汤鹏手造（武胜路凯德店）'},
#  {'address': '江岸区江汉北路6号循礼门饭店左侧永和豆浆旁',
#   'allCommentNum': 200,
#   'avgPrice': 13,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170575066,
#   'title': '一茶源（循礼门店）'},
#  {'address': '江岸区后湖路与建设渠路交汇处万锦江城2幢1层商号-1',
#   'allCommentNum': 1,
#   'avgPrice': 30,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170579831,
#   'title': '手工面包'},
#  {'address': '江汉区中山大道新佳丽广场1楼（屈臣氏对面）',
#   'allCommentNum': 408,
#   'avgPrice': 16,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170581950,
#   'title': '君子美芋（新佳丽广场店）'},
#  {'address': '江岸区百步亭花园路123号15栋1层7商室',
#   'allCommentNum': 6,
#   'avgPrice': 25,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170591864,
#   'title': '双糖烘焙'},
#  {'address': '硚口区解放大道387号大武汉家居广场R2座17层23号',
#   'allCommentNum': 1,
#   'avgPrice': 50,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170600310,
#   'title': '三颂屋甜品'},
#  {'address': '江岸区二七路224号中国物资储运仓库内二七路与工农兵交汇口（福轩酒楼正对面）',
#   'allCommentNum': 152,
#   'avgPrice': 35,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 92121111,
#   'title': '左巷小院咖啡厅'},
#  {'address': '武昌区积玉桥万达公馆13号楼2715室（积玉桥地铁A出口）',
#   'allCommentNum': 139,
#   'avgPrice': 50,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 119613312,
#   'title': '米嘟.cake手工烘焙'},
#  {'address': '东西湖区东西湖区东西湖大道6019号（吴家山六顺路恒春里377丽枫酒店斜对面）',
#   'allCommentNum': 9,
#   'avgPrice': 0,
#   'avgScore': 4.1,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 170623188,
#   'title': '雨纪烘培花艺工作室'},
#  {'address': '江岸区京汉大道未来家园百岁康大药房右侧',
#   'allCommentNum': 13,
#   'avgPrice': 34,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 171507963,
#   'title': 'Nikicake法式甜品与面包'},
#  {'address': '蔡甸区经开金街S19',
#   'allCommentNum': 53,
#   'avgPrice': 20,
#   'avgScore': 4.8,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 158689749,
#   'title': '可觅蛋糕'},
#  {'address': '洪山区金地格林东郡',
#   'allCommentNum': 4,
#   'avgPrice': 20,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 171600536,
#   'title': '拾光烘焙'},
#  {'address': '江夏区文化大道联投广场三楼',
#   'allCommentNum': 79,
#   'avgPrice': 15,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 171866868,
#   'title': '吾饮良品（联投广场万汇店）'},
#  {'address': '武昌区松竹路万达环球国际中心2号楼2722（洱湾酒店进入赏汉街）',
#   'allCommentNum': 3,
#   'avgPrice': 51,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 171868098,
#   'title': 'S house by 3pm'},
#  {'address': '洪山区东湖新技术开发区光谷8号二期的6幢2单元8层10号房',
#   'allCommentNum': 3,
#   'avgPrice': 45,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 171878248,
#   'title': '永恒生日蛋糕（乐享汇店）'},
#  {'address': '江夏区华师园北路',
#   'allCommentNum': 1,
#   'avgPrice': 10,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 171961089,
#   'title': '蔓斯雪'},
#  {'address': '江夏区藏龙岛杨桥湖大道Y1-S12商铺',
#   'allCommentNum': 2,
#   'avgPrice': 0,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 172050353,
#   'title': '湖边上咖啡生活馆'},
#  {'address': '江汉区新华路213号（取水楼公交站旁）',
#   'allCommentNum': 33,
#   'avgPrice': 17,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 172352547,
#   'title': '青沫茶颜（新华路取水楼店）'},
#  {'address': '江岸区黄兴路28号  长青广场E座四楼（万达影院旁）',
#   'allCommentNum': 40,
#   'avgPrice': 45,
#   'avgScore': 3.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 173460366,
#   'title': 'H&M甜品屋'},
#  {'address': '汉阳区江城大道绿地中央广场B区5-21号',
#   'allCommentNum': 0,
#   'avgPrice': 50,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 174439488,
#   'title': '奇米克蛋糕'},
#  {'address': '洪山区野芷湖西路安吉拉幼儿园旁',
#   'allCommentNum': 38,
#   'avgPrice': 34,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 174855404,
#   'title': '贞二的猫和酒'},
#  {'address': '武昌区粮道街224号（武汉中学西南2门斜对面）',
#   'allCommentNum': 28,
#   'avgPrice': 23,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 174877556,
#   'title': '厚颜吐司（粮道街直营店）'},
#  {'address': '江岸区台北街江汉北路164号云湖大厦1栋7层3室',
#   'allCommentNum': 139,
#   'avgPrice': 100,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 119657732,
#   'title': '焙客蛋糕'},
#  {'address': '洪山区雄楚大道1008号（万科锦程中心大厦底商）',
#   'allCommentNum': 31,
#   'avgPrice': 100,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 174928299,
#   'title': '慕蓝卡烘焙'},
#  {'address': '洪山区光谷德国风情街5号楼',
#   'allCommentNum': 101,
#   'avgPrice': 14,
#   'avgScore': 4.6,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 174932326,
#   'title': '布朗熊&茶'},
#  {'address': '洪山区致知街南湖时尚城K6栋2楼',
#   'allCommentNum': 46,
#   'avgPrice': 20,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 174933251,
#   'title': '三只小兽'},
#  {'address': '东西湖区东吴大道930号（中心广场旁）',
#   'allCommentNum': 114,
#   'avgPrice': 6,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 101770025,
#   'title': '豆花妈妈（吴家山店）'},
#  {'address': '蔡甸区民生路观澜御苑G1栋02层13室',
#   'allCommentNum': 0,
#   'avgPrice': 0,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 174935683,
#   'title': '贝诺蒂法式烘焙'},
#  {'address': '武昌区水果湖沙湖大道18号K5地块汉街万达广场B1层B1001-3B',
#   'allCommentNum': 435,
#   'avgPrice': 24,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 174949314,
#   'title': '鲍糕点（汉街万达店）'},
#  {'address': '江汉区解放大道武商广场二期三楼',
#   'allCommentNum': 208,
#   'avgPrice': 18,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 158803025,
#   'title': '泰芒了'},
#  {'address': '武昌区解放路368号',
#   'allCommentNum': 34,
#   'avgPrice': 20,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175065076,
#   'title': '都点星球'},
#  {'address': '洪山区团结大道仁和路金地广场E06商铺',
#   'allCommentNum': 49,
#   'avgPrice': 12,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175075847,
#   'title': '悟茶（金地自在城店）'},
#  {'address': '蔡甸区东风大道万达广场B3栋20楼',
#   'allCommentNum': 9,
#   'avgPrice': 38,
#   'avgScore': 4.3,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175134828,
#   'title': '静谧年华烘焙坊'},
#  {'address': '汉阳区高龙路广电·兰亭都荟小龙坎旁',
#   'allCommentNum': 56,
#   'avgPrice': 15,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175135889,
#   'title': '雅岛英皇茶（江腾广场店）'},
#  {'address': '青山区和平大道吾行里4号楼1层56号',
#   'allCommentNum': 49,
#   'avgPrice': 16,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175136023,
#   'title': '私厨花匠Branno（吾行里店）'},
#  {'address': '硚口区南国西汇一期负一层',
#   'allCommentNum': 38,
#   'avgPrice': 11,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175142888,
#   'title': '潮盖（南国西汇）'},
#  {'address': '汉阳区新福路新福茂中央广场四楼（金逸影城旁）',
#   'allCommentNum': 3,
#   'avgPrice': 14,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175205359,
#   'title': '东御皇茶'},
#  {'address': '江夏区谭鑫培路与文化大道交口东行150米路南',
#   'allCommentNum': 3,
#   'avgPrice': 12,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175265613,
#   'title': 'royaltea皇茶'},
#  {'address': '蔡甸区万达广场万达写字楼B3栋6楼16号（近体育中心）',
#   'allCommentNum': 249,
#   'avgPrice': 12,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 106558165,
#   'title': '初心DIY烘焙坊'},
#  {'address': '江汉区解放大道中山广场1楼102室（苏宁电器旁）',
#   'allCommentNum': 23,
#   'avgPrice': 26,
#   'avgScore': 0,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175301694,
#   'title': '然花面包主题餐厅'},
#  {'address': '东西湖区西二路舵落口广场22区智能软装博览中心一层',
#   'allCommentNum': 10,
#   'avgPrice': 7,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175301697,
#   'title': '港饮之港（舵落口店）'},
#  {'address': '武昌区八一路87号银海华庭3号楼办公楼B区3楼310室（洪山广场地铁B2出口直走）',
#   'allCommentNum': 11,
#   'avgPrice': 47,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175323948,
#   'title': '臻惜蛋糕工作室'},
#  {'address': '江岸区金桥大道24号欧亚达家居DS028后湖店1楼A1-27C号',
#   'allCommentNum': 7,
#   'avgPrice': 15,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175326305,
#   'title': 'LUCKY TEA 小确茶（后湖欧亚达店）'},
#  {'address': '洪山区书城路56号昊天大厦临街商铺',
#   'allCommentNum': 2,
#   'avgPrice': 31,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175327665,
#   'title': '書湘茶舍'},
#  {'address': '洪山区卓刀泉南路教育培训大楼1层6号',
#   'allCommentNum': 21,
#   'avgPrice': 19,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175333740,
#   'title': 'together一起茶'},
#  {'address': '江夏区金樱街花乐亿家底商',
#   'allCommentNum': 27,
#   'avgPrice': 70,
#   'avgScore': 4.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175349247,
#   'title': '蜜果蛋糕（大花岭店）'},
#  {'address': '武昌区徐家棚街街道团结大道长城嘉苑门口商铺（群星城旁）',
#   'allCommentNum': 33,
#   'avgPrice': 103,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 89268095,
#   'title': '威妮翻糖蛋糕'},
#  {'address': '东西湖区四明路吴南花园西区2栋102室（北冰洋生鲜对面）',
#   'allCommentNum': 0,
#   'avgPrice': 15,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175363593,
#   'title': '小梦甜时'},
#  {'address': '洪山区世界城光谷步行街4楼火星美食街外围观光电梯口',
#   'allCommentNum': 60,
#   'avgPrice': 16,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175366130,
#   'title': 'TEAMACC 茶玛（光谷店）'},
#  {'address': '汉阳区汉阳大道王家湾中央生活区第1幢16层10号房（不在小区内 一楼有Today）',
#   'allCommentNum': 27,
#   'avgPrice': 24,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175371192,
#   'title': '咪噜猫咖啡'},
#  {'address': '江汉区雪松路185号',
#   'allCommentNum': 16,
#   'avgPrice': 58,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 91411156,
#   'title': '小镇龙虾'},
#  {'address': '汉阳区汉阳大道王家湾中央生活区第1幢16层10号房（不在小区内 一楼有Today）',
#   'allCommentNum': 27,
#   'avgPrice': 24,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175371192,
#   'title': '咪噜猫咖啡'},
#  {'address': '江汉区雪松路185号',
#   'allCommentNum': 16,
#   'avgPrice': 58,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 91411156,
#   'title': '小镇龙虾'},
#  {'address': '洪山区雄楚大道高架下533号（武商量贩正门一楼）',
#   'allCommentNum': 19,
#   'avgPrice': 8,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175388073,
#   'title': '港饮之港（杨家湾武商量贩店）'},
#  {'address': '硚口区武胜路地铁k出口',
#   'allCommentNum': 41,
#   'avgPrice': 9,
#   'avgScore': 5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175398581,
#   'title': '港饮之港（武胜路地铁商城店）'},
#  {'address': '武昌区中山路昙华林泛悦汇负二楼',
#   'allCommentNum': 26,
#   'avgPrice': 15,
#   'avgScore': 4.2,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175482874,
#   'title': '乌所味'},
#  {'address': '武昌区岳家嘴地铁站G出口普提金商务中心B座2029号',
#   'allCommentNum': 4,
#   'avgPrice': 38,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175493693,
#   'title': 'Toy House'},
#  {'address': '东西湖区吴中街405号',
#   'allCommentNum': 0,
#   'avgPrice': 15,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175495573,
#   'title': '超级檬'},
#  {'address': '江夏区谭鑫培路万豪世纪天街3楼',
#   'allCommentNum': 5,
#   'avgPrice': 23,
#   'avgScore': 3.5,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175498025,
#   'title': '小确茶（万豪天街店）'},
#  {'address': '武昌区徐家棚街道和平大道绿地名邸公馆14栋二单元2902',
#   'allCommentNum': 4,
#   'avgPrice': 0,
#   'avgScore': 4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175504490,
#   'title': '卟咕花园·法式私厨'},
#  {'address': '江汉区长港路地铁E出口旁（摩非网咖旁）',
#   'allCommentNum': 23,
#   'avgPrice': 14,
#   'avgScore': 4.4,
#   'cate': '蛋糕甜点',
#   'cateId': '11',
#   'id': 175524063,
#   'title': '茶颜山（长港路地铁站店）'},
#  ...]
